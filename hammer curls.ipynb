# %%
import cv2
import mediapipe as mp
import numpy as np
import platform
import os

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

def play_beep():
    if platform.system() == 'Windows':
        import winsound
        winsound.Beep(1000, 150)
    else:
        duration = 0.15
        freq = 1000
        os.system(f'play -nq -t alsa synth {duration} sine {freq}')

def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    if angle > 180.0:
        angle = 360 - angle
    return angle

cap = cv2.VideoCapture(0)
counter = 0
stage = None

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = pose.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            landmarks = results.pose_landmarks.landmark
            shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                        landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

            angle = calculate_angle(shoulder, elbow, wrist)

            cv2.putText(image, str(int(angle)),
                        tuple(np.multiply(elbow, [640, 480]).astype(int)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2, cv2.LINE_AA)

            if angle > 160:
                stage = "down"
            if angle < 60 and stage == "down":
                stage = "up"
                counter += 1
                play_beep()
                print(f"Hammer Curl count: {counter}")

        except:
            pass

        cv2.rectangle(image, (0, 0), (300, 73), (245, 117, 16), -1)
        cv2.putText(image, 'HAMMER CURLS', (10, 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 1, cv2.LINE_AA)
        cv2.putText(image, str(counter),
                    (10, 60),
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.imshow('Hammer Curl Counter', image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# Hammer Curl count: 1
# Hammer Curl count: 2
# Hammer Curl count: 3
# Hammer Curl count: 4
# Hammer Curl count: 5
# Hammer Curl count: 6
# Hammer Curl count: 7
# Hammer Curl count: 8
# Hammer Curl count: 9
# Hammer Curl count: 10
# Hammer Curl count: 11
# Hammer Curl count: 12
# Hammer Curl count: 13
# Hammer Curl count: 14
# Hammer Curl count: 15
# Hammer Curl count: 16
# Hammer Curl count: 17
# Hammer Curl count: 18
# Hammer Curl count: 19
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 40
#      38 image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      39 image.flags.writeable = False
# ---> 40 results = pose.process(image)
#      41 image.flags.writeable = True
#      42 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solutions\pose.py:185, in Pose.process(self, image)
#     164 def process(self, image: np.ndarray) -> NamedTuple:
#     165   """Processes an RGB image and returns the pose landmarks on the most prominent person detected.
#     166
#     167   Args:
#    (...)    182          "enable_segmentation" is set to true.
#     183   """
# --> 185   results = super().process(input_data={'image': image})
#     186   if results.pose_landmarks:  # pytype: disable=attribute-error
#     187     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\mediapipe\python\solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:
